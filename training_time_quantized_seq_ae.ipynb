# %%
from __future__ import print_function

import numpy as np
import tensorflow as tf
import keras.backend as K
from keras.models import Model
from nltk.translate import bleu
from keras.utils import plot_model
from strsimpy.cosine import Cosine
from strsimpy.jaccard import Jaccard
from tensorflow.python.framework import ops
from strsimpy.levenshtein import Levenshtein
from keras.metrics import mean_squared_error as mse
from nltk.translate.bleu_score import SmoothingFunction
from keras.layers import Input, LSTM, Dense, Lambda, Concatenate

# %%
## CONFIGURATION

EPOCHS = 50
BATCH_SIZE = 64
NUM_SAMPLES = 50000
LATENT_DIMENSIONS = 32

DATA_PATH = 'fra-eng/fra.txt'

# %%
accepted_characters = sorted(list(" abcdefghijklmnopqrstuvwxyz1234567890"))

input_texts = []
target_texts = []

## DATA PREPROCESSING

with open(DATA_PATH, 'r', encoding = 'utf-8') as f:
    lines = f.read().split('\n')

for line in lines[: min(NUM_SAMPLES, len(lines) - 1)]:
    input_text, _, _ = line.split('\t')
    input_text = input_text.lower()
    input_text = "".join(char for char in input_text if char in accepted_characters)
    target_text = '\t' + input_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)    

num_encoder_tokens = len(accepted_characters)
num_decoder_tokens = num_encoder_tokens + 2
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(accepted_characters)])
target_token_index = dict([(char, i + 2) for i, char in enumerate(accepted_characters)])
target_token_index['\t'] = 0
target_token_index['\n'] = 1
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype = 'float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype = 'float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype = 'float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):        
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.
# Out:
# Number of samples: 50000
# Number of unique input tokens: 37
# Number of unique output tokens: 39
# Max sequence length for inputs: 22
# Max sequence length for outputs: 24

# %%
## DISCRETIZATION UTILS

def py_func(func, inp, Tout, stateful = True, name = None, grad = None):
    rnd_name = 'PyFuncGrad' + str(np.random.randint(0, 1e+8))
    tf.RegisterGradient(rnd_name)(grad)
    graph = tf.get_default_graph()
    with graph.gradient_override_map({"PyFunc": rnd_name}):
        return tf.py_func(func, inp, Tout, stateful = stateful, name = name)

def discrete_func(x, np_fn, name = None):
    with ops.name_scope(name, "Mysquare", [x]) as name:
        sqr_x = py_func(np_fn, [x], [tf.float32], name = name, grad = _identity_grad)  
        sqr_x[0].set_shape(x.shape)
        return sqr_x[0]

def _identity_grad(op, grad):
    return grad 

def binarize_np(x):
    a = np.zeros_like(x)
    a[x > 0.5] = 1
    return a

def Dis_Binarize():
    return Lambda(lambda x: discrete_func(x, binarize_np))

# %%
## AUTOENCODER MODEL DEFINITION
    
encoder_inputs = Input(shape = (None, num_encoder_tokens))
encoder_lstm = LSTM(LATENT_DIMENSIONS, return_state = True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
state_h_dense = Dense(LATENT_DIMENSIONS)
state_c_dense = Dense(LATENT_DIMENSIONS)
state_h = state_h_dense(state_h)
state_c = state_c_dense(state_c)

enc_states = Concatenate(axis = 1)([state_h, state_c])
before_discretization = enc_states
enc_states = Dis_Binarize()(enc_states)
discrete_state_h = Lambda(lambda x : x[:, :LATENT_DIMENSIONS])(enc_states)
discrete_state_c = Lambda(lambda x : x[:, LATENT_DIMENSIONS:])(enc_states)
encoder_states = [discrete_state_h, discrete_state_c]
after_discretization = K.stop_gradient(enc_states)

commit_loss = mse(after_discretization, before_discretization)

decoder_inputs = Input(shape = (None, num_decoder_tokens))
decoder_lstm = LSTM(LATENT_DIMENSIONS, return_sequences = True, return_state = True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state = encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation = 'softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.add_loss((0.2 / (2 * LATENT_DIMENSIONS)) * commit_loss)
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.summary()
plot_model(model)
# Out:
# WARNING:tensorflow:From <ipython-input-8-c2065c198d64>:8: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, 37)     0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 32), (None,  8960        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           1056        lstm_1[0][1]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           1056        lstm_1[0][2]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64)           0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 39)     0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32)           0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32)           0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 32), ( 9216        input_2[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, 39)     1287        lstm_2[0][0]
# ==================================================================================================
# Total params: 21,575
# Trainable params: 21,575
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## TRAINING (Done once per configuration)

model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split = 0.2)
model.save_weights('./model_weights/training_quantized/s2s_' + str(EPOCHS) + "_" + str(BATCH_SIZE) + "_" + str(NUM_SAMPLES) + "_" + str(LATENT_DIMENSIONS) + ".h5")
# Out:
# WARNING:tensorflow:From /usr0/home/vparimi/anaconda3/envs/gradai/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr0/home/vparimi/anaconda3/envs/gradai/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 20s 492us/step - loss: 2.1698 - accuracy: 0.4367 - val_loss: 2.4192 - val_accuracy: 0.3427
# Epoch 2/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 1.6521 - accuracy: 0.5500 - val_loss: 2.1374 - val_accuracy: 0.4279
# Epoch 3/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.5369 - accuracy: 0.5905 - val_loss: 2.1123 - val_accuracy: 0.4601
# Epoch 4/50
# 40000/40000 [==============================] - 16s 389us/step - loss: 1.4913 - accuracy: 0.6125 - val_loss: 2.1088 - val_accuracy: 0.4757
# Epoch 5/50
# 40000/40000 [==============================] - 16s 395us/step - loss: 1.4567 - accuracy: 0.6274 - val_loss: 2.1083 - val_accuracy: 0.4907
# Epoch 6/50
# 40000/40000 [==============================] - 16s 392us/step - loss: 1.4441 - accuracy: 0.6393 - val_loss: 2.1747 - val_accuracy: 0.5087
# Epoch 7/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 1.4686 - accuracy: 0.6511 - val_loss: 2.2449 - val_accuracy: 0.5211
# Epoch 8/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.5333 - accuracy: 0.6614 - val_loss: 2.3305 - val_accuracy: 0.5355
# Epoch 9/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.6022 - accuracy: 0.6718 - val_loss: 2.3826 - val_accuracy: 0.5495
# Epoch 10/50
# 40000/40000 [==============================] - 16s 397us/step - loss: 1.6680 - accuracy: 0.6787 - val_loss: 2.4496 - val_accuracy: 0.5518
# Epoch 11/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.6936 - accuracy: 0.6840 - val_loss: 2.4834 - val_accuracy: 0.5614
# Epoch 12/50
# 40000/40000 [==============================] - 16s 394us/step - loss: 1.7052 - accuracy: 0.6887 - val_loss: 2.5634 - val_accuracy: 0.5650
# Epoch 13/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 1.7157 - accuracy: 0.6925 - val_loss: 2.6388 - val_accuracy: 0.5555
# Epoch 14/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 1.7340 - accuracy: 0.6963 - val_loss: 2.7295 - val_accuracy: 0.5750
# Epoch 15/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.7543 - accuracy: 0.6991 - val_loss: 2.8260 - val_accuracy: 0.5746
# Epoch 16/50
# 40000/40000 [==============================] - 16s 392us/step - loss: 1.7824 - accuracy: 0.7021 - val_loss: 2.8912 - val_accuracy: 0.5713
# Epoch 17/50
# 40000/40000 [==============================] - 16s 398us/step - loss: 1.8256 - accuracy: 0.7057 - val_loss: 2.9697 - val_accuracy: 0.5789
# Epoch 18/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.8531 - accuracy: 0.7082 - val_loss: 3.1910 - val_accuracy: 0.5823
# Epoch 19/50
# 40000/40000 [==============================] - 16s 395us/step - loss: 1.8806 - accuracy: 0.7108 - val_loss: 3.4016 - val_accuracy: 0.5756
# Epoch 20/50
# 40000/40000 [==============================] - 16s 396us/step - loss: 1.8962 - accuracy: 0.7131 - val_loss: 3.4324 - val_accuracy: 0.5836
# Epoch 21/50
# 40000/40000 [==============================] - 16s 399us/step - loss: 1.9113 - accuracy: 0.7151 - val_loss: 3.6773 - val_accuracy: 0.5885
# Epoch 22/50
# 40000/40000 [==============================] - 16s 399us/step - loss: 1.9549 - accuracy: 0.7169 - val_loss: 3.8802 - val_accuracy: 0.5893
# Epoch 23/50
# 40000/40000 [==============================] - 16s 398us/step - loss: 1.9843 - accuracy: 0.7183 - val_loss: 3.8260 - val_accuracy: 0.5921
# Epoch 24/50
# 40000/40000 [==============================] - 16s 398us/step - loss: 1.9891 - accuracy: 0.7205 - val_loss: 4.0559 - val_accuracy: 0.5928
# Epoch 25/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.0186 - accuracy: 0.7220 - val_loss: 4.2751 - val_accuracy: 0.5936
# Epoch 26/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.0472 - accuracy: 0.7235 - val_loss: 4.2503 - val_accuracy: 0.5995
# Epoch 27/50
# 40000/40000 [==============================] - 16s 395us/step - loss: 2.0661 - accuracy: 0.7250 - val_loss: 4.6841 - val_accuracy: 0.5945
# Epoch 28/50
# 40000/40000 [==============================] - 16s 392us/step - loss: 2.0929 - accuracy: 0.7260 - val_loss: 4.5824 - val_accuracy: 0.5995
# Epoch 29/50
# 40000/40000 [==============================] - 16s 392us/step - loss: 2.1153 - accuracy: 0.7274 - val_loss: 4.7231 - val_accuracy: 0.5991
# Epoch 30/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 2.1317 - accuracy: 0.7286 - val_loss: 5.2090 - val_accuracy: 0.6030
# Epoch 31/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 2.1306 - accuracy: 0.7297 - val_loss: 5.1859 - val_accuracy: 0.6013
# Epoch 32/50
# 40000/40000 [==============================] - 16s 394us/step - loss: 2.1519 - accuracy: 0.7310 - val_loss: 5.1219 - val_accuracy: 0.6047
# Epoch 33/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.1908 - accuracy: 0.7318 - val_loss: 5.3856 - val_accuracy: 0.5997
# Epoch 34/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.1964 - accuracy: 0.7328 - val_loss: 5.3360 - val_accuracy: 0.6019
# Epoch 35/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 2.1991 - accuracy: 0.7336 - val_loss: 5.6433 - val_accuracy: 0.6058
# Epoch 36/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.1900 - accuracy: 0.7346 - val_loss: 5.4485 - val_accuracy: 0.6061
# Epoch 37/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.1849 - accuracy: 0.7355 - val_loss: 5.5410 - val_accuracy: 0.6093
# Epoch 38/50
# 40000/40000 [==============================] - 16s 393us/step - loss: 2.1915 - accuracy: 0.7363 - val_loss: 5.5296 - val_accuracy: 0.6043
# Epoch 39/50
# 40000/40000 [==============================] - 16s 395us/step - loss: 2.2153 - accuracy: 0.7371 - val_loss: 5.4057 - val_accuracy: 0.6150
# Epoch 40/50
# 40000/40000 [==============================] - 16s 394us/step - loss: 2.2312 - accuracy: 0.7380 - val_loss: 5.7747 - val_accuracy: 0.6157
# Epoch 41/50
# 40000/40000 [==============================] - 16s 391us/step - loss: 2.2839 - accuracy: 0.7387 - val_loss: 5.7580 - val_accuracy: 0.6079
# Epoch 42/50
# 40000/40000 [==============================] - 16s 397us/step - loss: 2.2733 - accuracy: 0.7399 - val_loss: 6.0892 - val_accuracy: 0.6153
# Epoch 43/50
# 40000/40000 [==============================] - 16s 401us/step - loss: 2.2838 - accuracy: 0.7403 - val_loss: 5.4860 - val_accuracy: 0.6108
# Epoch 44/50
# 40000/40000 [==============================] - 17s 423us/step - loss: 2.3292 - accuracy: 0.7413 - val_loss: 5.7930 - val_accuracy: 0.6180
# Epoch 45/50
# 40000/40000 [==============================] - 19s 468us/step - loss: 2.3500 - accuracy: 0.7416 - val_loss: 6.1448 - val_accuracy: 0.6184
# Epoch 46/50
# 40000/40000 [==============================] - 20s 493us/step - loss: 2.3824 - accuracy: 0.7427 - val_loss: 6.2014 - val_accuracy: 0.6177
# Epoch 47/50
# 40000/40000 [==============================] - 20s 504us/step - loss: 2.3983 - accuracy: 0.7433 - val_loss: 6.5852 - val_accuracy: 0.6206
# Epoch 48/50
# 40000/40000 [==============================] - 21s 530us/step - loss: 2.4368 - accuracy: 0.7437 - val_loss: 6.2622 - val_accuracy: 0.6130
# Epoch 49/50
# 40000/40000 [==============================] - 22s 554us/step - loss: 2.4659 - accuracy: 0.7441 - val_loss: 6.3543 - val_accuracy: 0.6232
# Epoch 50/50
# 40000/40000 [==============================] - 21s 537us/step - loss: 2.4642 - accuracy: 0.7448 - val_loss: 6.6751 - val_accuracy: 0.6217

# %%
## LOADING PRETRAINED WEIGHTS

model.load_weights('./model_weights/training_quantized/s2s_' + str(EPOCHS) + "_" + str(BATCH_SIZE) + "_" + str(NUM_SAMPLES) + "_" + str(LATENT_DIMENSIONS) + ".h5")

# %%
## INFERENCE MODEL

encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape = (LATENT_DIMENSIONS,))
decoder_state_input_c = Input(shape = (LATENT_DIMENSIONS,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state = decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)
    
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index['\t']] = 1.

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        if (sampled_char == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        states_value = [h, c]

    return decoded_sentence

# %%
## VALIDATION TESTING

start = int(NUM_SAMPLES * 0.9) + 100
samples = 100

bleu_val = 0
cosine_val = 0
jaccard_val = 0
levenshtein_val = 0

cosine = Cosine(1)
jaccard = Jaccard(1)
levenshtein = Levenshtein()
smoothie = SmoothingFunction().method4

for seq_index in range(start, start + samples):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    
    cosine_val += cosine.distance(input_texts[seq_index], decoded_sentence)
    jaccard_val += jaccard.distance(input_texts[seq_index], decoded_sentence)
    levenshtein_val += levenshtein.distance(input_texts[seq_index], decoded_sentence)
    bleu_val += bleu([input_texts[seq_index].split()], decoded_sentence.split(), smoothing_function = smoothie)    
    
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Training Time Quantized Decoded sentence:', decoded_sentence)
    
print("BLEU Score = ", round(1. - (bleu_val / samples), 4))
print("Cosine Score = ", round(cosine_val / samples, 4))
print("Jaccard Score = ", round(jaccard_val / samples, 4))
print("Levenshtein Score = ", round(levenshtein_val / samples, 4))
# Out:
# -
# Input sentence: when will you be back
# Training Time Quantized Decoded sentence: who dont do your tom
#
# -
# Input sentence: when will you be free
# Training Time Quantized Decoded sentence: who dont do your took
#
# -
# Input sentence: when will you be free
# Training Time Quantized Decoded sentence: who dont do your took
#
# -
# Input sentence: where are my children
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where are my scissors
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are my slippers
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are my slippers
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are my slippers
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are my trousers
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are my trousers
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are our friends
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are the glasses
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are the glasses
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are the showers
# Training Time Quantized Decoded sentence: whats your so the come
#
# -
# Input sentence: where are the toilets
# Training Time Quantized Decoded sentence: whats your so the come
#
# -
# Input sentence: where are the victims
# Training Time Quantized Decoded sentence: what a see the colds
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you heading
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are you staying
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where are you staying
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where are you working
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where are your gloves
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where are your people
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: where are your things
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where are your things
# Training Time Quantized Decoded sentence: where should you sain
#
# -
# Input sentence: where can i reach you
# Training Time Quantized Decoded sentence: whose your to start
#
# -
# Input sentence: where can i reach you
# Training Time Quantized Decoded sentence: whose your to start
#
# -
# Input sentence: where did you grow up
# Training Time Quantized Decoded sentence: who are you seat it
#
# -
# Input sentence: where did you grow up
# Training Time Quantized Decoded sentence: who are you seat it
#
# -
# Input sentence: where did you guys go
# Training Time Quantized Decoded sentence: who are you seat her
#
# -
# Input sentence: where did you hide it
# Training Time Quantized Decoded sentence: who anyone the cold you
#
# -
# Input sentence: where did you hide it
# Training Time Quantized Decoded sentence: who anyone the cold you
#
# -
# Input sentence: where did you hide it
# Training Time Quantized Decoded sentence: who anyone the cold you
#
# -
# Input sentence: where did you hide it
# Training Time Quantized Decoded sentence: who anyone the cold you
#
# -
# Input sentence: where do you all live
# Training Time Quantized Decoded sentence: whon to should that
#
# -
# Input sentence: where do you live now
# Training Time Quantized Decoded sentence: who are you seat here
#
# -
# Input sentence: where do you work now
# Training Time Quantized Decoded sentence: who are you seat the
#
# -
# Input sentence: where do you work now
# Training Time Quantized Decoded sentence: who are you seat the
#
# -
# Input sentence: where exactly are you
# Training Time Quantized Decoded sentence: where some the come
#
# -
# Input sentence: where exactly are you
# Training Time Quantized Decoded sentence: where some the come
#
# -
# Input sentence: where is tom sleeping
# Training Time Quantized Decoded sentence: where you so the come
#
# -
# Input sentence: where is my newspaper
# Training Time Quantized Decoded sentence: whos your too started
#
# -
# Input sentence: where is my newspaper
# Training Time Quantized Decoded sentence: whos your too started
#
# -
# Input sentence: where is the bathroom
# Training Time Quantized Decoded sentence: what do you so the dog
#
# -
# Input sentence: where is the bathroom
# Training Time Quantized Decoded sentence: what do you so the dog
#
# -
# Input sentence: where is the bathroom
# Training Time Quantized Decoded sentence: what do you so the dog
#
# -
# Input sentence: where is the bus stop
# Training Time Quantized Decoded sentence: whos a book the come
#
# -
# Input sentence: where is the elevator
# Training Time Quantized Decoded sentence: where you so a looks
#
# -
# Input sentence: where is the elevator
# Training Time Quantized Decoded sentence: where you so a looks
#
# -
# Input sentence: where is the evidence
# Training Time Quantized Decoded sentence: whose your to starte
#
# -
# Input sentence: where is your luggage
# Training Time Quantized Decoded sentence: who are your to stary
#
# -
# Input sentence: where is your luggage
# Training Time Quantized Decoded sentence: who are your to stary
#
# -
# Input sentence: where should i put it
# Training Time Quantized Decoded sentence: whose your to started
#
# -
# Input sentence: where should i put it
# Training Time Quantized Decoded sentence: whose your to started
#
# -
# Input sentence: where should i put it
# Training Time Quantized Decoded sentence: whose your to started
#
# -
# Input sentence: where was your father
# Training Time Quantized Decoded sentence: what do you so the dog
#
# -
# Input sentence: where was your father
# Training Time Quantized Decoded sentence: what do you so the dog
#
# -
# Input sentence: where were all of you
# Training Time Quantized Decoded sentence: where is you stilly
#
# -
# Input sentence: where were all of you
# Training Time Quantized Decoded sentence: where is you stilly
#
# -
# Input sentence: where were the others
# Training Time Quantized Decoded sentence: what a not a see there
#
# -
# Input sentence: where were the police
# Training Time Quantized Decoded sentence: whos a should the do
#
# -
# Input sentence: where were they going
# Training Time Quantized Decoded sentence: whos a book the come
#
# -
# Input sentence: where were they going
# Training Time Quantized Decoded sentence: whos a book the come
#
# -
# Input sentence: where were you hiding
# Training Time Quantized Decoded sentence: where is you stilly
#
# -
# Input sentence: where were you hiding
# Training Time Quantized Decoded sentence: where is you stilly
#
# -
# Input sentence: wherere toms things
# Training Time Quantized Decoded sentence: whats your so the go
#
# -
# Input sentence: wheres everyone else
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres everyone else
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres my microphone
# Training Time Quantized Decoded sentence: what a see the cold
#
# -
# Input sentence: wheres my other shoe
# Training Time Quantized Decoded sentence: what a see the cold
#
# -
# Input sentence: wheres the red cross
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres the red cross
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres the newspaper
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres your daughter
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres your daughter
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres your passport
# Training Time Quantized Decoded sentence: wheres your so there
#
# -
# Input sentence: wheres your suitcase
# Training Time Quantized Decoded sentence: where some the come
#
# -
# Input sentence: which is your luggage
# Training Time Quantized Decoded sentence: who should you still
#
# -
# Input sentence: which is your luggage
# Training Time Quantized Decoded sentence: who should you still
#
# -
# Input sentence: which team are you on
# Training Time Quantized Decoded sentence: why want to shor it
#
# -
# Input sentence: who am i talking with
# Training Time Quantized Decoded sentence: who should you still
#
# -
# Input sentence: who are you afraid of
# Training Time Quantized Decoded sentence: who anyone the comeay
#
# -
# Input sentence: who are you to decide
# Training Time Quantized Decoded sentence: who dont a should out
#
# -
# Input sentence: who are you to decide
# Training Time Quantized Decoded sentence: who dont a should out
#
# -
# Input sentence: who asked tom to sing
# Training Time Quantized Decoded sentence: why dont do you stil
#
# -
# Input sentence: who asked you to sing
# Training Time Quantized Decoded sentence: who all the ready us
#
# -
# Input sentence: who ate all the fruit
# Training Time Quantized Decoded sentence: who anyone the comeay
#
# -
# Input sentence: who broke this window
# Training Time Quantized Decoded sentence: who dont do your this
#
# -
# Input sentence: who built the snowman
# Training Time Quantized Decoded sentence: who is the better it
#
# -
# Input sentence: who cares about facts
# Training Time Quantized Decoded sentence: who are your to stary
# -
# Input sentence: who closed the window
# Training Time Quantized Decoded sentence: who dont do the cold
#
# -
# Input sentence: who crashed the party
# Training Time Quantized Decoded sentence: who are your to stary
#
# -
# Input sentence: who did you come with
# Training Time Quantized Decoded sentence: who did you so the go
#
# -
# Input sentence: who did you talk with
# Training Time Quantized Decoded sentence: who did you so the go
#
# -
# Input sentence: who do you think i am
# Training Time Quantized Decoded sentence: who did you so the go
#
# -
# Input sentence: who else is out there
# Training Time Quantized Decoded sentence: who dont do your that
#
# BLEU Score =  0.8612
# Cosine Score =  0.2194
# Jaccard Score =  0.4125
# Levenshtein Score =  13.66
